# %%
import importlib as oe
import porespy as ps
import Generators as gen
from Plotting import ImagePlotter
import matplotlib.pylab as plt
import gc
import numpy as np
import metrics_images as mtr
gc.collect()
# Out:
# 20

# %%
oe.reload(gen)
# Usage Example
# Generate texture
generator = gen.Micro2D_Generator()
gc.collect()
# Out:
# Keys in the HDF5 file: ['AngEllipse', 'GRF', 'NBSA', 'RandomEllipse', 'VoidSmall', 'VoidSmallBig', 'VoronoiLarge', 'VoronoiMedium', 'VoronoiMediumSpaced', 'VoronoiSmall']
# Number of Images AngEllipse : 8000
# Number of Images GRF : 10000
# Number of Images NBSA : 1634
# Number of Images RandomEllipse : 8000
# Number of Images VoidSmall : 9989
# Number of Images VoidSmallBig : 10000
# Number of Images VoronoiLarge : 10000
# Number of Images VoronoiMedium : 10000
# Number of Images VoronoiMediumSpaced : 9756
# Number of Images VoronoiSmall : 10000
# 711

# %%
texture_data = generator.generate('AngEllipse',count=6281)
print(generator.porosity)
# Plot the result
ImagePlotter.plot(texture_data, title=generator.file_name)
# ImagePlotter.plot(generator.data_spring, title=generator.model_name)
# Save in multiple formats
# generator.to_csv()
# generator.to_png()
# generator.save_all()
# generator.binarize_data(percentile_val=30)
# generator.to_png()
# Out:
# Number of Images : 8000
# 0.1518402099609375

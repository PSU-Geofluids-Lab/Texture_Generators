# %%
import importlib as oe
import Generators as gen
import porespy as ps
from Generators import RandomGenerator
from Plotting import ImagePlotter
import matplotlib.pylab as plt
import gc
import numpy as np
import metrics_images as mtr
gc.collect()
# Out:
# 8

# %%
oe.reload(gen)
# Usage Example
# Generate texture
generator = gen.Graph_Generators(p=0.2,epsilon=.3)
texture_data = generator.generate('fractal_hierarchy')
generator.make_spatial_realization()

# Plot the result
#ImagePlotter.plot(texture_data, title=generator.model_name)
ImagePlotter.plot(generator.data_spring, title=generator.model_name)
# Save in multiple formats
# generator.to_csv()
# generator.to_png()
# generator.save_all()
# generator.binarize_data(percentile_val=30)
# generator.to_png()
gc.collect()
print(generator.porosity)
# Out:
# Number of Models : 14
#  Model Names :
# ER	spatial	spatialWS	blocks_assortative	overlapping_communities	nestedness	maximal_stars	core_distance	fractal_leaves	fractal_root	fractal_hierarchy	fractal_star	perlin_noise	disconnected_cliques
# Iteration - porosity target : 0.0078125, Iteration 0
# Iteration - porosity target : 0.0155029296875, Iteration 1
# Iteration - porosity target : 0.02325439453125, Iteration 2
# Iteration - porosity target : 0.0308837890625, Iteration 3
# Iteration - porosity target : 0.03826904296875, Iteration 4
# Iteration - porosity target : 0.0455322265625, Iteration 5
# Iteration - porosity target : 0.05303955078125, Iteration 6
# Iteration - porosity target : 0.060302734375, Iteration 7
# Iteration - porosity target : 0.0675048828125, Iteration 8
# Iteration - porosity target : 0.07476806640625, Iteration 9
# Iteration - porosity target : 0.08154296875, Iteration 10
# Iteration - porosity target : 0.08880615234375, Iteration 11
# Iteration - porosity target : 0.0953369140625, Iteration 12
# Iteration - porosity target : 0.10211181640625, Iteration 13
# Done with the graph Spatial representation generation
# 0.10211181640625

# %%
generator.size
# Out:
# 128

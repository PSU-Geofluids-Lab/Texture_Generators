# %%
import importlib as oe
import Generators as gen
import porespy as ps
from Generators import RandomGenerator
from Plotting import ImagePlotter
import matplotlib.pylab as plt
import gc
import numpy as np
import metrics_images as mtr
gc.collect()
# Out:
# [23:36:30] ERROR    PARDISO solver not installed, run `pip install pypardiso`. Otherwise,          ]8;id=312252;file:///home/tqm5707/anaconda3/envs/Series2Vec/lib/python3.12/site-packages/openpnm/utils/_workspace.py\_workspace.py]8;;\:]8;id=343884;file:///home/tqm5707/anaconda3/envs/Series2Vec/lib/python3.12/site-packages/openpnm/utils/_workspace.py#56\56]8;;\
#                     simulations will be slow. Apple M chips not supported.
# Please install opencv for full functionality related to image color to grayscale
# 20

# %%
oe.reload(gen)
# Usage Example
# Generate texture
generator = gen.Graph_Generators(p=0.2,epsilon=.3)
texture_data = generator.generate('fractal_hierarchy')
generator.make_spatial_realization()

# Plot the result
#ImagePlotter.plot(texture_data, title=generator.model_name)
ImagePlotter.plot(generator.data_spring, title=generator.model_name)
# Save in multiple formats
# generator.to_csv()
# generator.to_png()
# generator.save_all()
# generator.binarize_data(percentile_val=30)
# generator.to_png()
gc.collect()
print(generator.porosity)
# Out:
# Number of Models : 14
#  Model Names :
# ER	spatial	spatialWS	blocks_assortative	overlapping_communities	nestedness	maximal_stars	core_distance	fractal_leaves	fractal_root	fractal_hierarchy	fractal_star	perlin_noise	disconnected_cliques
# Iteration - porosity target : 0.0078125, Iteration 0
# Iteration - porosity target : 0.01556396484375, Iteration 1
# Iteration - porosity target : 0.02301025390625, Iteration 2
# Iteration - porosity target : 0.030517578125, Iteration 3
# Iteration - porosity target : 0.03778076171875, Iteration 4
# Iteration - porosity target : 0.044921875, Iteration 5
# Iteration - porosity target : 0.052001953125, Iteration 6
# Iteration - porosity target : 0.0589599609375, Iteration 7
# Iteration - porosity target : 0.066162109375, Iteration 8
# Iteration - porosity target : 0.0728759765625, Iteration 9
# Iteration - porosity target : 0.07928466796875, Iteration 10
# Iteration - porosity target : 0.086181640625, Iteration 11
# Iteration - porosity target : 0.0924072265625, Iteration 12
# Iteration - porosity target : 0.0992431640625, Iteration 13
# Iteration - porosity target : 0.10540771484375, Iteration 14
# Iteration - porosity target : 0.11212158203125, Iteration 15
# Iteration - porosity target : 0.11895751953125, Iteration 16
# Iteration - porosity target : 0.1251220703125, Iteration 17
# Iteration - porosity target : 0.1312255859375, Iteration 18
# Iteration - porosity target : 0.13726806640625, Iteration 19
# Iteration - porosity target : 0.14404296875, Iteration 20
# Iteration - porosity target : 0.14996337890625, Iteration 21
# Iteration - porosity target : 0.15594482421875, Iteration 22
# Iteration - porosity target : 0.161865234375, Iteration 23
# Iteration - porosity target : 0.1680908203125, Iteration 24
# Iteration - porosity target : 0.17413330078125, Iteration 25
# Iteration - porosity target : 0.17913818359375, Iteration 26
# Iteration - porosity target : 0.18438720703125, Iteration 27
# Iteration - porosity target : 0.18914794921875, Iteration 28
# Iteration - porosity target : 0.19482421875, Iteration 29
# Iteration - porosity target : 0.19952392578125, Iteration 30
# Iteration - porosity target : 0.205322265625, Iteration 31
# Iteration - porosity target : 0.21044921875, Iteration 32
# Iteration - porosity target : 0.21563720703125, Iteration 33
# Iteration - porosity target : 0.22064208984375, Iteration 34
# Iteration - porosity target : 0.225830078125, Iteration 35
# Iteration - porosity target : 0.230224609375, Iteration 36
# Iteration - porosity target : 0.2354736328125, Iteration 37
# Iteration - porosity target : 0.239501953125, Iteration 38
# Iteration - porosity target : 0.24517822265625, Iteration 39
# Iteration - porosity target : 0.249755859375, Iteration 40
# Iteration - porosity target : 0.25469970703125, Iteration 41
# Iteration - porosity target : 0.25933837890625, Iteration 42
# Iteration - porosity target : 0.2633056640625, Iteration 43
# Iteration - porosity target : 0.267822265625, Iteration 44
# Iteration - porosity target : 0.27197265625, Iteration 45
# Iteration - porosity target : 0.2764892578125, Iteration 46
# Iteration - porosity target : 0.28021240234375, Iteration 47
# Iteration - porosity target : 0.28314208984375, Iteration 48
# Iteration - porosity target : 0.28814697265625, Iteration 49
# Iteration - porosity target : 0.29278564453125, Iteration 50
# Iteration - porosity target : 0.29681396484375, Iteration 51
# Iteration - porosity target : 0.30169677734375, Iteration 52
# Done with the graph Spatial representation generation
# 0.30169677734375

# %%
oe.reload(gen)
# Usage Example
# Generate texture
generator = gen.Graph_NetworkX_Generators(size=128)
texture_data = generator.generate('connected_caveman_graph')
#texture_data = generator.generate('gaussian_random_partition_graph',s=20,v=1,p_in=.4,p_out=0.01)
generator.make_spatial_realization(target_porosity=0.1)

# Plot the result
#ImagePlotter.plot(texture_data, title=generator.model_name)
ImagePlotter.plot(generator.data, title=generator.model_name)
# Save in multiple formats
# generator.to_csv()
# generator.to_png()
# generator.save_all()
# generator.binarize_data(percentile_val=30)
# generator.to_png()
gc.collect()
print(generator.porosity)
# Out:
# Number of Models : 7
#  Model Names :
# fast_gnp_random_graph	connected_caveman_graph	margulis_gabber_galil_graph	newman_watts_strogatz_graph	watts_strogatz_graph	barabasi_albert_graph	gaussian_random_partition_graph
# Metadata : {'size': 128, 'generator_type': 'Graph_NetworkX_Generators/', 'generator_reference': 'NetworkX', 'l': 32, 'k': 4, 'model_name': 'connected_caveman_graph', 'porosity': 0.0234375}
# ERROR! Session/line number was not unique in database. History logging moved to new session 616
# Iteration - porosity target : 0.00738525390625, Iteration 0
# Iteration - porosity target : 0.0150146484375, Iteration 1
# Iteration - porosity target : 0.02264404296875, Iteration 2
# Iteration - porosity target : 0.03009033203125, Iteration 3
# Iteration - porosity target : 0.0372314453125, Iteration 4
# Iteration - porosity target : 0.04449462890625, Iteration 5
# Iteration - porosity target : 0.05181884765625, Iteration 6
# Iteration - porosity target : 0.05938720703125, Iteration 7
# Iteration - porosity target : 0.06683349609375, Iteration 8
# Iteration - porosity target : 0.0740966796875, Iteration 9
# Iteration - porosity target : 0.0811767578125, Iteration 10
# Iteration - porosity target : 0.0882568359375, Iteration 11
# Iteration - porosity target : 0.0946044921875, Iteration 12
# Iteration - porosity target : 0.10198974609375, Iteration 13
# Done with the graph Spatial representation generation
# 0.10198974609375

# %%
oe.reload(gen)

# Usage Example
if __name__ == "__main__":
    # Generate texture
    generator = gen.VariogramGenerator(size=128,name='test1')
    texture_data =generator.generate(transform_field=False,transform_mode=['ZinnHarvey'],
                                     var=.2,len_scale=10,angles=np.pi/3)
    
    #Plot the result
    ImagePlotter.plot(texture_data, title='Variogram Texture')
gc.collect()
# Out:
# Using seed: 3123178934
# Metadata : {'generator_type': 'VariogramGenerator/test1/', 'size': 128, 'seed': 3123178934, 'cov_model': 'Gaussian', 'cov_model_dim': 2, 'cov_model_var': 0.2, 'cov_model_len_scale': 10, 'cov_model_angles': 1.0471975511965976, 'cov_model_transform_field': False, 'transform_mode': ['ZinnHarvey']}
# 5537

# %%
oe.reload(gen)
# Generate texture
generator = gen.Variogram_PGGenerator(size=128,name='test1')
generator.generate_fields(0,transform_field=False,transform_mode=['ZinnHarvey'],
                                 var=.2,len_scale=10,angles=np.pi/3)
generator.generate_fields(1,transform_field=True,transform_mode=['ZinnHarvey'],
                                 var=.2,len_scale=10,angles=np.pi/3)

texture_data = generator.generate(plot_all=True)
#Plot the result
#ImagePlotter.plot(texture_data, title='Variogram Texture')
gc.collect()
# Out:
# Using seed: 502849462
# Metadata : {'generator_type': 'Variogram_PGGenerator/test1/', 'size': 128, 'seed_0': 502849462, 'cov_model_0': 'Gaussian', 'cov_model_dim_0': 2, 'cov_model_var_0': 0.2, 'cov_model_len_scale_0': 10, 'cov_model_angles_0': 1.0471975511965976, 'cov_model_transform_field_0': False, 'transform_mode_0': ['ZinnHarvey']}
# Using seed: 3516570998
# Metadata : {'generator_type': 'Variogram_PGGenerator/test1/', 'size': 128, 'seed_0': 502849462, 'cov_model_0': 'Gaussian', 'cov_model_dim_0': 2, 'cov_model_var_0': 0.2, 'cov_model_len_scale_0': 10, 'cov_model_angles_0': 1.0471975511965976, 'cov_model_transform_field_0': False, 'transform_mode_0': ['ZinnHarvey'], 'seed_1': 3516570998, 'cov_model_1': 'Gaussian', 'cov_model_dim_1': 2, 'cov_model_var_1': 0.2, 'cov_model_len_scale_1': 10, 'cov_model_angles_1': 1.0471975511965976, 'cov_model_transform_field_1': True, 'transform_mode_1': ['ZinnHarvey']}
# [200, 200]
# 15753

# %%
generator.norm_fields
# Out:
# {}

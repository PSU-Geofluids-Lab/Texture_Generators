# %%
from Generators import RandomGenerator
from Plotting import ImagePlotter

# %%
# Usage Example
if __name__ == "__main__":
    # Generate texture
    base_name = "texture"
    generator = RandomGenerator(size=(128, 128),name=base_name)
    texture_data = generator.generate()

    # Plot the result
    ImagePlotter.plot(texture_data, title='Random Texture')
# Out:
# Using seed: 2734002426
# 2025-06-20 14:43:22.302 (  47.873s) [    7DFBF4575740]         vtkDataSet.cxx:765   WARN| vtkImageData (0x5ff7dc429fe0): Point array intensity with 1 components, has 32768 tuples but there are only 16384 points
# All Files saved
